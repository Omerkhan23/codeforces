# %%
n = int(input())
print(n)
while n > 1 :
    
    if n % 2 == 0:
        n = int(n/2)
    else:
        
        n = (n*3) + 1
    print(n)
# Out:
# 7
# 22
# 11
# 34
# 17
# 52
# 26
# 13
# 40
# 20
# 10
# 5
# 16
# 8
# 4
# 2
# 1
